# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
#"C:\Users\amara\Downloads\clean-data-2020-04-29-csv-2.csv"

import pandas as pd

df = pd.read_csv("C:/Users/amara/Downloads/clean-data-2020-04-29-csv-2.csv" , encoding = "latin")
df.head(5)
# Out:
#    number   who_id dataset prop_id who_region country_territory_area  iso  \
# 0       1  ACAPS_1   ACAPS       1       EMRO            Afghanistan  AFG
# 1       2  ACAPS_2   ACAPS       2       EMRO            Afghanistan  AFG
# 2       3  ACAPS_3   ACAPS       3       EMRO            Afghanistan  AFG
# 3       4  ACAPS_4   ACAPS       4       EMRO            Afghanistan  AFG
# 4       5  ACAPS_5   ACAPS       5       EMRO            Afghanistan  AFG
#
#    iso_3166_1_numeric admin_level area_covered  ...  \
# 0                   4    national          NaN  ...
# 1                   4       other        Kabul  ...
# 2                   4    national          NaN  ...
# 3                   4    national          NaN  ...
# 4                   4    national          NaN  ...
#
#                     comments non_compliance  \
# 0                        NaN            NaN
# 1                        NaN            NaN
# 2                        NaN            NaN
# ...

# %%
import pandas as pd
df = pd.read_csv("C:/Users/amara/Downloads/clean-data-2020-04-29-csv-2.csv",encoding = "latin")
df.tail(5)
# Out:
#        number          who_id    dataset prop_id who_region  \
# 27549   27983  CSHVienna_3270  CSHVienna    3271       EURO
# 27550   27984  CSHVienna_3271  CSHVienna    3272       EURO
# 27551   27985  CSHVienna_3272  CSHVienna    3273       EURO
# 27552   27986  CSHVienna_3273  CSHVienna    3274       EURO
# 27553   27987  CSHVienna_3274  CSHVienna    3275       EURO
#
#                                   country_territory_area  iso  \
# 27549  United Kingdom Of Great Britain And Northern I...  GBR
# 27550  United Kingdom Of Great Britain And Northern I...  GBR
# 27551  United Kingdom Of Great Britain And Northern I...  GBR
# 27552  United Kingdom Of Great Britain And Northern I...  GBR
# 27553  United Kingdom Of Great Britain And Northern I...  GBR
#
#        iso_3166_1_numeric admin_level    area_covered  ...  \
# 27549                 826       other  United Kingdom  ...
# 27550                 826       other  United Kingdom  ...
# ...
